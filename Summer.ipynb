# %% [markdown]
# ## Summer Olympics Data Analysis Assignment

# %% [markdown]
# ## 1. In how many cities Summer Olympics is held so far?

# %%
import pandas as pd
import  numpy as np

# %%
df = pd.read_csv('summer.csv')

# %%
df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
df['City'].unique()
# Out:
# array(['Athens', 'Paris', 'St Louis', 'London', 'Stockholm', 'Antwerp',
#        'Amsterdam', 'Los Angeles', 'Berlin', 'Helsinki',
#        'Melbourne / Stockholm', 'Rome', 'Tokyo', 'Mexico', 'Munich',
#        'Montreal', 'Moscow', 'Seoul', 'Barcelona', 'Atlanta', 'Sydney',
#        'Beijing'], dtype=object)

# %%
print("No. of cities ==  ", len( df['City'].unique()))  

for city in df['City'].unique():
    
    print(city)
# Out:
# No. of cities ==   22
# Athens
# Paris
# St Louis
# London
# Stockholm
# Antwerp
# Amsterdam
# Los Angeles
# Berlin
# Helsinki
# Melbourne / Stockholm
# Rome
# Tokyo
# Mexico
# Munich
# Montreal
# Moscow
# Seoul
# Barcelona
# Atlanta
# Sydney
# Beijing

# %% [markdown]
# ## 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
data= []

for sport in df['Sport'].unique():
    d = df[df['Sport'] == sport][df['Medal']=='Gold']
    data.append([sport , len(d)])
# Out:
# <ipython-input-6-2046a0e051aa>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   d = df[df['Sport'] == sport][df['Medal']=='Gold']

# %%
pd.DataFrame(data,columns=['Sport' , 'No of Gold medals']).sort_values(by = 'No of Gold medals' , ascending=False).head()
# Out:
#          Sport  No of Gold medals
# 0     Aquatics               1421
# 1    Athletics               1215
# 17      Rowing                890
# 4   Gymnastics                820
# 3      Fencing                552

# %%
pd.DataFrame(data,columns=['Sport' , 'No of Gold medals']).sort_values(by = 'No of Gold medals' , ascending=False).head().plot(x='Sport' , y='No of Gold medals' , kind='bar' , figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Sport'>

# %% [markdown]
# ## 3. Which sport is having most number of  Medals so far? (Top 5)

# %%
df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
data =[]
for sport in df['Sport'].unique():
    data.append([sport,len(df[df['Sport'] == sport])])

data = pd.DataFrame(data, columns = ['Sport','Medals'])
data = data.sort_values(by = 'Medals', ascending = False).head()

# %%
data
# Out:
#          Sport  Medals
# 0     Aquatics    4170
# 1    Athletics    3638
# 17      Rowing    2667
# 4   Gymnastics    2307
# 3      Fencing    1613

# %%
data.plot(x= 'Sport' ,y = 'Medals' ,kind='bar')
# Out:
# <AxesSubplot:xlabel='Sport'>

# %% [markdown]
# ## 4. Which player has won most number of medals? (Top 5)

# %%
df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
players =[]

for athlete in df['Athlete'].unique():
  players.append([athlete,len(df[df['Athlete'] == athlete])])
players = pd.DataFrame(players,columns=['Athlete','Medals'])

# %%
players = players.sort_values(by ='Medals', ascending =False).head()

# %%
players
# Out:
#                     Athlete  Medals
# 18640       PHELPS, Michael      22
# 7197       LATYNINA, Larisa      18
# 9948     ANDRIANOV, Nikolay      15
# 6591           ONO, Takashi      13
# 5103   MANGIAROTTI, Edoardo      13

# %%
players.plot(x='Athlete', y = 'Medals', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %% [markdown]
# ## 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
data= []

for athlete in df['Athlete'].unique():
    d = df[df['Athlete'] == athlete][df['Medal']=='Gold']
    data.append([athlete , len(d)])
# Out:
# <ipython-input-23-7c9f2b899c94>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   d = df[df['Athlete'] == athlete][df['Medal']=='Gold']

# %%
data
# Out:
# [['HAJOS, Alfred', 2],
#  ['HERSCHMANN, Otto', 0],
#  ['DRIVAS, Dimitrios', 0],
#  ['MALOKINIS, Ioannis', 1],
#  ['CHASAPIS, Spiridon', 0],
#  ['CHOROPHAS, Efstathios', 0],
#  ['ANDREOU, Joannis', 0],
#  ['NEUMANN, Paul', 1],
#  ['PEPANOS, Antonios', 0],
#  ['LANE, Francis', 0],
#  ['SZOKOLYI, Alajos', 0],
#  ['BURKE, Thomas', 2],
#  ['HOFMANN, Fritz', 2],
#  ['CURTIS, Thomas', 1],
#  ['GOULDING, Grantley', 0],
#  ['LERMUSIAUX, Albin', 0],
#  ['FLACK, Edwin', 2],
#  ['BLAKE, Arthur', 0],
#  ['GMELIN, Charles', 0],
#  ['JAMISON, Herbert', 0],
#  ['GOLEMIS, Dimitrios', 0],
#  ['DANI, Nandor', 0],
#  ['VERSIS, Sotirios', 0],
#  ['GARRETT, Robert', 2],
#  ['PARASKEVOPOULOS, Panagiotis', 0],
#  ['CLARK, Ellery', 2],
#  ['CONNOLLY, James', 1],
#  ['KELLNER, Gyula', 0],
#  ['LOUIS, Spyridon', 1],
#  ['VASILAKOS, Kharilaos', 0],
#  ['DAMASKOS, Evangelos', 0],
#  ['THEODOROPOULOS, Ioannis', 0],
#  ['HOYT, William Welles', 1],
#  ['TYLER, Albert', 0],
#  ['PAPASIDERIS, Georgios', 0],
# ...

# %%
data=pd.DataFrame(data,columns=['Athlete' , 'No of Gold medals']).sort_values(by = 'No of Gold medals' , ascending=False).head().plot(x='Athlete' , y='No of Gold medals' , kind='bar' , figsize=(10,5))

# %% [markdown]
# ## 6. In which year India won first Gold Medal in Summer Olympics?

# %%
ind =  df[df['Country'] == 'IND']

ind
# Out:
#        Year       City      Sport           Discipline               Athlete  \
# 241    1900      Paris  Athletics            Athletics     PRITCHARD, Norman
# 244    1900      Paris  Athletics            Athletics     PRITCHARD, Norman
# 5512   1928  Amsterdam     Hockey               Hockey  ALLEN, Richard James
# 5513   1928  Amsterdam     Hockey               Hockey           CHAND, Dyan
# 5514   1928  Amsterdam     Hockey               Hockey   GATELEY, Maurice A.
# ...     ...        ...        ...                  ...                   ...
# 29879  2012     London     Boxing               Boxing             KOM, Mary
# 30841  2012     London   Shooting             Shooting         NARANG, Gagan
# 30849  2012     London   Shooting             Shooting          KUMAR, Vijay
# 31111  2012     London  Wrestling  Wrestling Freestyle       DUTT, Yogeshwar
# 31118  2012     London  Wrestling  Wrestling Freestyle         KUMAR, Sushil
#
# ...

# %%
ig = ind[ind['Medal'] == 'Gold']

ig
# Out:
#        Year       City     Sport Discipline                       Athlete  \
# 5512   1928  Amsterdam    Hockey     Hockey          ALLEN, Richard James
# 5513   1928  Amsterdam    Hockey     Hockey                   CHAND, Dyan
# 5514   1928  Amsterdam    Hockey     Hockey           GATELEY, Maurice A.
# 5515   1928  Amsterdam    Hockey     Hockey                   GILL, K. S.
# 5516   1928  Amsterdam    Hockey     Hockey  GOODSIR-CULLEN, William John
# ...     ...        ...       ...        ...                           ...
# 16099  1980     Moscow    Hockey     Hockey                  SINGH, Singh
# 16100  1980     Moscow    Hockey     Hockey               SURINDER, Singh
# 16101  1980     Moscow    Hockey     Hockey           SYLVANUS, Dung Dung
# 16102  1980     Moscow    Hockey     Hockey                  ZAFAR, Zafar
# 28856  2008    Beijing  Shooting   Shooting               BINDRA, Abhinav
#
#       Country Gender                     Event Medal
# ...

# %% [markdown]
# ## "INDIA WON THE FIRST GOLD MEDAL IN 1928"

# %% [markdown]
# ## 7. Which event is most popular in terms on number of players? (Top 5)

# %%
pop_event = []
for event in df['Event'].unique():
 pop_event.append([event,len(df[df['Event'] == event])])

# %%
pop_event = pd.DataFrame(pop_event,columns = ['Event','No. of players'])
pop_event = pop_event.sort_values(by='No. of players',ascending = False).head()

# %%
pop_event
# Out:
#                 Event  No. of players
# 80           Football            1497
# 176            Hockey            1422
# 138  Team Competition            1147
# 327        Basketball            1012
# 337          Handball             973

# %%
pop_event.plot(x = 'Event', y = 'No. of players', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Event'>

# %% [markdown]
# ## 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
data=df[df['Gender']=='Women']

data
# Out:
#        Year    City      Sport           Discipline                   Athlete  \
# 416    1900   Paris       Golf                 Golf              PRATT, Daria
# 417    1900   Paris       Golf                 Golf     ABBOTT, Margaret Ives
# 418    1900   Paris       Golf                 Golf         WHITTIER, Pauline
# 639    1900   Paris     Tennis               Tennis             JONES, Marion
# 640    1900   Paris     Tennis               Tennis         ROSENBAUM, Hedwig
# ...     ...     ...        ...                  ...                       ...
# 31116  2012  London  Wrestling  Wrestling Freestyle           VOLOSOVA, Lubov
# 31121  2012  London  Wrestling  Wrestling Freestyle        VOROBIEVA, Natalia
# 31122  2012  London  Wrestling  Wrestling Freestyle  HRISTOVA, Stanka Zlateva
# 31123  2012  London  Wrestling  Wrestling Freestyle          MANYUROVA, Guzel
# 31124  2012  London  Wrestling  Wrestling Freestyle              UNDA, Maider
#
# ...

# %%
data1= []

for sport in data['Sport'].unique():
    d = data[data['Sport'] == sport][df['Medal']=='Gold']
    data1.append([sport , len(d)])
# Out:
# <ipython-input-37-dcedc43942a2>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   d = data[data['Sport'] == sport][df['Medal']=='Gold']

# %%
pd.DataFrame(data1,columns=['Sport' , 'No of Gold medals']).sort_values(by = 'No of Gold medals' , ascending=False).head()
# Out:
#          Sport  No of Gold medals
# 4     Aquatics                589
# 8    Athletics                389
# 9   Gymnastics                268
# 14      Rowing                217
# 11  Volleyball                166

# %%
pd.DataFrame(data1,columns=['Sport' , 'No of Gold medals']).sort_values(by = 'No of Gold medals' , ascending=False).head().plot(x='Sport' , y='No of Gold medals' , kind='bar' , figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Sport'>
